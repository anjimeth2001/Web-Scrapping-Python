# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time
import pandas as pd

# URL
url = "https://www.espncricinfo.com/series/lanka-premier-league-2024-1421415/jaffna-kings-vs-kandy-falcons-qualifier-2-1428481/ball-by-ball-commentary"

# Chrome setup
options = Options()
options.add_argument("--start-maximized")
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage") 

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options) 
driver.set_page_load_timeout(60)  # avoid long waits
driver.get(url)
time.sleep(6)  # wait for page load

data = []

# gradually scroll and capture
previous_count = 0
while True:
    # find all visible balls
    balls = driver.find_elements(By.CSS_SELECTOR, "span.ds-text-tight-s.ds-font-regular.ds-mb-1.lg\\:ds-mb-0.lg\\:ds-mr-3.ds-block.ds-text-center.ds-text-typo-mid1")
    
    # scrape new ones only
    for i in range(previous_count, len(balls)):
        ball = balls[i]
        ball_no = ball.text.strip()
        try:
            parent = ball.find_element(By.XPATH, "../../..")
            desc_div = parent.find_element(By.CSS_SELECTOR, "div.ds-ml-4.lg\\:ds-ml-3.ds-text-typo-mid1")
            desc = desc_div.text.strip().replace("\n", " ")
            print(f"{ball_no} ➜ {desc}")
            data.append({"Ball": ball_no, "Commentary": desc})
        except Exception as e:
            print(f"Skipping {ball_no}: {e}")
    
    previous_count = len(balls)
    
    # scroll down to load more
    driver.execute_script("window.scrollBy(0, 1500);")
    time.sleep(3)
    
    # break when no new balls load
    new_balls = driver.find_elements(By.CSS_SELECTOR, "span.ds-text-tight-s.ds-font-regular.ds-mb-1.lg\\:ds-mb-0.lg\\:ds-mr-3.ds-block.ds-text-center.ds-text-typo-mid1")
    if len(new_balls) == previous_count:
        break

# close driver
driver.quit()

# convert to DataFrame
df = pd.DataFrame(data)
df.to_csv("Q2.csv", index=False, encoding="utf-8-sig")
print("\n✅ Saved to Q2.csv")

Anjitha Methmadu
# Out:
# 19.6 ➜ Asitha Fernando to Ramesh Mendis, 2 runs Jaffna hold their nerve! What a game, what a finish! Low full-toss, darted on the pads, and all Mendis can do is hack this to deep midwicket. They run back for the second, but the throw is safely into Kusal Mendis's hands. Jaffna win by one run!
# 19.5 ➜ Asitha Fernando to Ramesh Mendis, SIX runs And he's found it! Low full-toss and Ramesh Mendis has absolutely smoked this straight down the ground, through the line and all the way
# 19.4 ➜ Asitha Fernando to Ramesh Mendis, 2 runs Cracking yorker on off, dug out down the ground to long-on. They scramble for a desperate two but the throw misses the stumps
# 19.3 ➜ Asitha Fernando to Ramesh Mendis, FOUR runs Finds the boundary! Full on off, just misses the yorker length. Clears the front leg, frees the arms, high elbow lofted straight drive and there's no chance for long-off
# 19.2 ➜ Asitha Fernando to Ramesh Mendis, no run low full-toss chipped to long-on on the bounce. Mendis turns down the single. Was that the right move? Rathnayake is no tailender
# 19.1 ➜ Asitha Fernando to Rathnayake, 1 run Starts with an excellent yorker, squeezed out to long-on
# 18.6 ➜ Behrendorff to Rathnayake, 1 run Another yorker, low full-toss really, drilled to long-on
# 18.5 ➜ Behrendorff to Rathnayake, 2 runs Good yorker, whipped to deep midwicket. They hustle back for two
# 18.4 ➜ Behrendorff to Rathnayake, SIX runs And it's gone for a maximum! Wow, wow, wow. Misses the yorker and Pavan has just launched this over long-on
# 18.4 ➜ Behrendorff to Ramesh Mendis, (no ball) 1 run Balls gone, the BAT'S gone, and it's caught to boot! This was a high full-toss outside off. Mendis hacks at it, and ends up slicing it to backward point, while his bat went to square leg. They go upstairs to check for a waist high no-ball, and the third umpire says it is. Pretty tight in my opinion, but umpire Ruchira Palliyaguruge was certain
# 18.3 ➜ Behrendorff to Ramesh Mendis, no run full toss outside off, Mendis goes across the wicket and sweeps it, but straight to backward square leg
# 18.2 ➜ Behrendorff to Ramesh Mendis, SIX runs Swivel pulled away over deep midwicket! Skips down the track, it's a back of a length slower ball. His eyes are not really on this, but he goes through the shot and somehow he middles the pants off it
# 18.1 ➜ Behrendorff to Ramesh Mendis, FOUR runs Good start! Back of a length outside, forehand over mid-off, just whacked away
# 17.6 ➜ Allen to Ramesh Mendis, 1 run good length on the stumps, nudged to midwicket for one
# 17.5 ➜ Allen to Ramesh Mendis, FOUR runs Reverse sweep for four! This was chipped to Asitha at short third, who is unsure whether to go for the catch or stay back, in the end he's in no man's land and this spins away from him and races away
# 17.4 ➜ Allen to Rathnayake, 1 run good length outside off, pushed into the covers off the back foot for one
# 17.3 ➜ Allen to Angelo Mathews, OUT Fabian Allen is having the day of all days! This one is fuller, and arrowed in. Mathews looks to heave this onside and misses. On any other day this is a simply a dot ball, but on Fabian Allen Day, it ricochets off the thigh guard and clatters into the stumps
# 17.2 ➜ Allen to Angelo Mathews, 2 runs good length outside off, this time punched into the covers
# 17.1 ➜ Allen to Angelo Mathews, no run good length wide outside off, swing and a miss
# 16.6 ➜ Behrendorff to Chaturanga, OUT Direct hit just when they needed it! Chaturanga backs away and drives this fuller one on darted in straight to extra cover. He wants the single but Mathews correctly turns him back. The throw from Nissanka though is a bullet and Chaturanga is barely in the frame
# 16.5 ➜ Behrendorff to Angelo Mathews, 1 run back of a length on the pads, worked to deep square leg. Just the one
# 16.4 ➜ Behrendorff to Angelo Mathews, FOUR runs Clears short fine! Short again, again gets inside the line but this time is able to get enough on it to clear the man in the circle behind square
# 16.3 ➜ Behrendorff to Angelo Mathews, no run Slower one short of a length, swings and misses. This bounces over leg stump, so no wide given
# 16.2 ➜ Behrendorff to Chaturanga, 1 run short of a length just on off, backs away and chops this to mid-off
# 16.1 ➜ Behrendorff to Angelo Mathews, 1 run Slower one short of a length just outside off, 115kph, controlled pulled to deep square leg
# 15.6 ➜ Allen to Shanaka, OUT Allen you absolute beauty! Good length, pitches on leg, grips and turns to strike the top of off stump. Shanaka, the hero last time out, is gone early here as goes for the big slog across the line and misses completely
# 15.5 ➜ Allen to Shanaka, 2 runs good length on the stumps, makes room and pokes this into the offside
# 15.4 ➜ Allen to Angelo Mathews, 1 run good length on the stumps, worked to long-on off the front foot
# 15.3 ➜ Allen to Angelo Mathews, FOUR runs Edged and four! Pushed through quick wide of off, Mathews has a ungainly swing but gets a thick bottom edge past the keeper
# 15.2 ➜ Allen to Shanaka, 1 run length on off, 92kph, backs away and swats it it square on the off side
# 15.1 ➜ Allen to Angelo Mathews, 1 run darted on the pads, turned to short fine for one
# 14.6 ➜ Viyaskanth to Shanaka, no run Huge appeal for leg before! Not out says the umpire. It's the googly and Shanaka has not read it. He is caught on the crease and it's strikes him just above the knee roll. They opt not to review.
# 14.5 ➜ Viyaskanth to Kamindu Mendis, OUT Huuuuge wicket! Viyaskanth has tossed it up, bravely, but this time it's the googly. Kamindu goes once more for the slog sweep but this time he doesn't get the connection. There's still a lot of work to do though at long-on, but DDS makes good ground and holds on to this under pressure
# 14.4 ➜ Viyaskanth to Kamindu Mendis, SIX runs Here we go! Kamindu breaks the shackles! This was short of length, Kamindu is waiting on one knee and he just wallops it over deep square leg
# 14.3 ➜ Viyaskanth to Angelo Mathews, 1 run low full toss but only a single as Mathews swings it away to deep midwicket
# 14.2 ➜ Viyaskanth to Angelo Mathews, no run wide yorker almost, dug out as point cuts it off
# 14.1 ➜ Viyaskanth to Kamindu Mendis, 1 run good length on the stumps, heaved to wide long-on in the air briefly
# 13.6 ➜ Dhananjaya to Kamindu Mendis, 1 run full on off, driven to long-off
# 13.5 ➜ Dhananjaya to Angelo Mathews, 1 run short of a length on the stumps, clubbed to deep midwicket
# 13.4 ➜ Dhananjaya to Kamindu Mendis, 1 run tossed up on off, looks for the reverse and just about gets some glove on this. Through the keepers legs
# 13.3 ➜ Dhananjaya to Angelo Mathews, 1 run good length on off, dragged to midwicket off the back foot
# 13.2 ➜ Dhananjaya to Angelo Mathews, no run good length and flat outside off, play and a miss with little foot movement
# 13.1 ➜ Dhananjaya to Angelo Mathews, no run darted in quick on off, 93kph, knocked to Dhananjaya's right as he dives and stops it
# 12.6 ➜ Viyaskanth to Angelo Mathews, 1 run full outside off, pushes this to long-off for one
# 12.5 ➜ Viyaskanth to Hasaranga, OUT Viyaskanth has the Kandy skipper! This was tossed up, but it's a good length wide of off. Looks to go against spin and launch it over long-on. Ends up splicing it towards long-off where - who else? - Fabian Allen is lurking to settle under yet another catch
# 12.4 ➜ Viyaskanth to Kamindu Mendis, 1 run short of a length on the stumps, pulled to deep midwicket. Kamindu lets out a groan of frustration
# 12.3 ➜ Viyaskanth to Hasaranga, 1 run goes back and nudges this through midwicket for
# 12.2 ➜ Viyaskanth to Hasaranga, SIX runs Inside out over extra cover! Another one tossed up, Wanindu makes room, leans back and just launches this into his favoured region
# 12.1 ➜ Viyaskanth to Hasaranga, FOUR runs Well placed! Tossed up on leg, Hasaranga clears the front foot and heaves this between the boundary riders at deep midwicket and long-on
# 11.6 ➜ Asitha Fernando to Kamindu Mendis, FOUR runs Edged for four! Back of a length, angled away from off. Kamindu looks to swing this away over mid-on, but gets a very fortunate inside edge that runs away fine
# 11.5 ➜ Asitha Fernando to Hasaranga, 1 run attempted yorker on leg stump, dug out to midwicket for a quick single
# 11.4 ➜ Asitha Fernando to Hasaranga, no run Well directed bouncer! Wanindu clears that front leg as a first motion, but this one is right on him as he sways out of the way
# 11.3 ➜ Asitha Fernando to Kamindu Mendis, 1 run skips down the track and swings it down to deep midwicket
# 11.2 ➜ Asitha Fernando to Hasaranga, 1 run full on middle and leg, Hasaranga stays deep in the crease and looks to work it onside. Ends up getting a leading edge almost, in the air but well short of long-on
# 11.1 ➜ Asitha Fernando to Kamindu Mendis, 1 run full outside off, slapped straight to mid-off. Kamindu missed out on this one
# 10.6 ➜ Viyaskanth to Hasaranga, no run good length just outside off, defensive push to backward point
# 10.5 ➜ Viyaskanth to Mohammad Haris, OUT Haris's wild innings comes to an end! And it's Fabian Allen in the action once again! Haris comes down the track as Viyaskanth holds the length back a touch, looks to hoick it over long on but ends up slicing it high into the Colombo sky. Allen sprints around from long-on and holds on to a very well judged catch
# 10.4 ➜ Viyaskanth to Kamindu Mendis, 1 run darted in on the boots, whipped through square leg
# 10.3 ➜ Viyaskanth to Mohammad Haris, 1 run goes back and works this through midwicket
# 10.2 ➜ Viyaskanth to Kamindu Mendis, 1 run skips down the track and lifts this into the vacant midwicket region
# 10.1 ➜ Viyaskanth to Mohammad Haris, 1 run Another hilarious effort from Haris! Looks to take this from outside off and paddle it over fine, ends up scooping it high over the keeper. Falls wide of short third
# 9.6 ➜ Dhananjaya to Mohammad Haris, 1 run darted in on the pads as Haris looked to make room. Worked to deep backward square leg
# 9.5 ➜ Dhananjaya to Kamindu Mendis, 1 run good length on off, gets forward and nurdles this through midwicket for one
# 9.4 ➜ Dhananjaya to Kamindu Mendis, no run Huge appeal for caught behind as this one slides down leg, Kamindu looks to sweep but doesn't connect. They go upstairs to review, but not sure there was any bat on this. Definitely glances the pad on the way through - likely the sound Mendis heard behind the stumps. Not out.
# 9.3 ➜ Dhananjaya to Mohammad Haris, 1 run fuller on the pads, glanced fine for one
# 9.2 ➜ Dhananjaya to Mohammad Haris, SIX runs Haris goes hard! Too short from DDS, and this is bread and cheese for Haris who just rocks back and monsters this pull over deep square leg
# 9.1 ➜ Dhananjaya to Kamindu Mendis, 1 run back of a length on off, punched to long-on
# 8.6 ➜ Viyaskanth to Mohammad Haris, no run lovely googly, rips back in sharply, and Haris who was caught on the crease does well to get some bat on this. Inside edge into his pads
# 8.5 ➜ Viyaskanth to Mohammad Haris, 2 runs good length on off, again. Reverse sweep, chipped high and just beats the man at short third
# 8.4 ➜ Viyaskanth to Mohammad Haris, no run good length just outside off, 91kph, gives this one a little more air. Misses the cut
# 8.3 ➜ Viyaskanth to Kamindu Mendis, 1 run good length on the stumps, 95kph, swept to deep square leg
# 8.2 ➜ Viyaskanth to Kamindu Mendis, 2 runs short of a length, 99kph, on the stumps, worked to the left of long-on for a couple
# 8.1 ➜ Viyaskanth to Kamindu Mendis, no run good length outside off, 91kph, comes down the track but straight back to the bowler
# 7.6 ➜ Dhananjaya to Kamindu Mendis, 1 run swept behind square now for a single
# 7.5 ➜ Dhananjaya to Kamindu Mendis, FOUR runs Clears the extra cover! Tossed up outside off and Kamindu executes this cover drive to perfection
# 7.4 ➜ Dhananjaya to Mohammad Haris, 1 run short of a length on the stumps, pulled to deep midwicket
# 7.3 ➜ Dhananjaya to Kamindu Mendis, 1 run back of a length, pushed through flatter on off. Pulled to long-on
# 7.2 ➜ Dhananjaya to Kamindu Mendis, no run full and wide, slapped straight to short extra cover
# 7.1 ➜ Dhananjaya to Kamindu Mendis, 2 runs good length outside off from around the wicket, driven into the covers for a couple
# 6.6 ➜ Allen to Mohammad Haris, 2 runs fuller on off, driven wide of long-off for a couple
# 6.5 ➜ Allen to Mohammad Haris, no run short of a length outside off, cut square straight to cover
# 6.4 ➜ Allen to Kamindu Mendis, 1 run tossed up outside off from over the wicket, steps across and works it through midwicket
# 6.3 ➜ Allen to Fletcher, OUT And this time it's right through him! Very similar to the last one but this one is straighter. Fletcher again shapes up to cut but has to adjust late. Doesn't read the arm ball and looks to just block, but he's late on the stroke as this zips through to crash into off stump
# 6.2 ➜ Allen to Fletcher, no run this one is pushed through quicker outside off as Fletcher chops it on to his pads
# 6.1 ➜ Allen to Fletcher, no run grip and turn away from off, as Fletcher makes too much room on the leg side
# 5.6 ➜ Asitha Fernando to Mohammad Haris, no run slower one outside off on a length, cuts and gets an edge but it bounces through to the keeper
# 5.5 ➜ Asitha Fernando to Fletcher, 1 run full on the pads, clipped to deep backward square leg. Fletcher hobbles gingerly to the other side
# 5.4 ➜ Asitha Fernando to Fletcher, no run cracking yorker, squeezed out just about
# 5.3 ➜ Asitha Fernando to Mohammad Haris, 1 run pulled to deep square leg for one
# 5.2 ➜ Asitha Fernando to Mohammad Haris, SIX runs What an unreal shot! How do I even describe it? Reverse swat, off the back of the bat that has just flown fine of short third man all the way for six! Just how, it was a low full-toss as well
# 5.2 ➜ Asitha Fernando to Mohammad Haris, 1 wide looks for another yorker, but slides down leg. Wide given as the bowler thinks there's something on it
# 5.1 ➜ Asitha Fernando to Fletcher, 1 leg bye Lovely yorker, just manages to squeeze this behind square on the leg side for one. Seems to have missed the bat and on to the boot
# 4.6 ➜ Allen to Mohammad Haris, FOUR runs Clubbed down the ground! Tossed up on leg, backs away, leans back and smacks it down the ground. Beats long-off. 50 up for Kandy
# 4.5 ➜ Allen to Mohammad Haris, no run skips down the track and looks to heave this against the spin. Inside edge into the pads
# 4.4 ➜ Allen to Mohammad Haris, no run back of a length just outside off, looks to cut and misses as this turns away from the right hander
# 4.3 ➜ Allen to Mohammad Haris, no run full on the stumps, hacked to mid-on
# 4.2 ➜ Allen to Mohammad Haris, no run Full outside off, squeezed to mid-off
# 4.1 ➜ Allen to Chandimal, OUT Chandimal is gone! Allen is ecstatic! This one drifted in full and deflects straight off Chandimal's boot before careening into middle stump. The Kandy coach has his head in his hands, he knows how important that wicket is
# 3.6 ➜ Azmatullah to Fletcher, no run Searing yorker, and one that Fletcher has done really well to just keep out
# 3.5 ➜ Azmatullah to Fletcher, FOUR runs Lifted over backward point! Back of a length outside off, skips down the track, adjusts to the short length, uses the pace and just lifts it over the infield
# 3.4 ➜ Azmatullah to Fletcher, no run Shuffles down the track again, this time looks to go through the offside, but it's slapped straight to mid-off
# 3.3 ➜ Azmatullah to Fletcher, SIX runs Three in three! Skips down the track, makes this slower length ball into a fuller one and just launches it over cow corner
# 3.2 ➜ Azmatullah to Fletcher, SIX runs Even bigger! Drags the length back but same result. Just a short-arm jab but this sails over deep midwicket!
# 3.1 ➜ Azmatullah to Fletcher, SIX runs Greeted with a six! So, so good from Fletcher. Good length but too straight. He gets inside the line and just flicks it over deep backward square leg
# 2.6 ➜ Behrendorff to Chandimal, FOUR runs And salt in the wounds! Short of a length and this pull has been clattered in front of square
# 2.5 ➜ Behrendorff to Fletcher, 1 run Nearly a run out! Another one pace-off and Fletcher dabs it to backward point. The run is just not on but they take it. All the man has to do is hit the stumps but he misses. Chandimal would have been out my metres
# 2.4 ➜ Behrendorff to Fletcher, no run Swing and a miss! Back of length on the stumps. Looks to pull this but is early on the stroker
# 2.3 ➜ Behrendorff to Fletcher, FOUR runs Muscled away! Good length just outside, Fletcher just hacks across the line and beats the diving midwicket. Not much timing but a lot of power
# 2.2 ➜ Behrendorff to Fletcher, no run Good length, pace-off, wicket to wicket. Appeal for leg before and given! Insta-review from Fletcher! And the replays vindicate him, clear inside edge on this. It might have been pitching just outside leg as well
# 2.1 ➜ Behrendorff to Chandimal, 1 run back of a length on off, push and run towards cover
# 1.6 ➜ Asitha Fernando to Fletcher, FOUR runs Just about clears short fine leg! Back of a length but on leg, gets inside the line and whips it fine. Behrendorff has height on his side, but even he can't leap and grab this one
# 1.5 ➜ Asitha Fernando to Fletcher, no run back of a length, and hurries him this time. Looks to cut but this is too close to him, inside edge into the pads
# 1.4 ➜ Asitha Fernando to Fletcher, SIX runs Glorious! Good length on off, but this drive from Fletcher is oustanding. Sumptuous check-drive straight into the sightscreen, quality stuff
# 1.3 ➜ Asitha Fernando to Fletcher, no run full on the pads, whipped straight to midwicket
# 1.2 ➜ Asitha Fernando to Chandimal, 1 run Whipped away, but somehow the man at deep backward square saves the boundary! Back of a length on middle and Chandimal picks it up, it races to the boundary rider but he does well to just get his body behind it
# 1.1 ➜ Asitha Fernando to Chandimal, no run back of a length on off, defended into the turf off the back foot
# 0.6 ➜ Behrendorff to Fletcher, no run back of a length outside off, dabbed straight to backward point
# 0.5 ➜ Behrendorff to Chandimal, 1 run back of a length on off, runs this down behind point for one
# 0.4 ➜ Behrendorff to Chandimal, no run back of a length, nips in and cramps Chandimal for room
# 0.3 ➜ Behrendorff to Chandimal, FOUR runs Chipped through midwicket! This was fuller and shaping in a touch on middle and leg, but Chandimal does well to get that front foot out of the way and flicks it away
# 0.2 ➜ Behrendorff to Chandimal, no run Good carry! Back of a length, pitches on middle and leg and goes across the right hander. Beats him well
# 0.1 ➜ Behrendorff to Chandimal, no run back of a length on off, defended off the back foot
#
# ✅ Saved to Q2.csv

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
import re

# ESPN Cricinfo Match URL
url = "https://www.espncricinfo.com/series/lanka-premier-league-2024-1421415/jaffna-kings-vs-kandy-falcons-qualifier-2-1428481/ball-by-ball-commentary"

# Selenium setup
options = Options()
options.add_argument("--start-maximized")
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.get(url)
time.sleep(6)  # Wait for page to fully load

data = []
previous_count = 0

print("\n🏏 Starting ball-by-ball scraping...\n")

while True:
    # Find all visible ball numbers
    balls = driver.find_elements(By.CSS_SELECTOR, 
        "span.ds-text-tight-s.ds-font-regular.ds-mb-1.lg\\:ds-mb-0.lg\\:ds-mr-3.ds-block.ds-text-center.ds-text-typo-mid1")

    # Process newly loaded balls
    for i in range(previous_count, len(balls)):
        ball = balls[i]
        ball_no = ball.text.strip()

        try:
            parent = ball.find_element(By.XPATH, "../../..")
            desc_div = parent.find_element(By.CSS_SELECTOR, "div.ds-ml-4.lg\\:ds-ml-3.ds-text-typo-mid1")
            commentary = desc_div.text.strip().replace("\n", " ")

            # --- Parse fields ---
            over, ball_part = ball_no.split(".") if "." in ball_no else (ball_no, "")
            bowler = batter = runs = extra = ""

            # Pattern: "Bowler to Batter, Something"
            match = re.match(r"(.+?) to (.*?), (.+)", commentary)
            if match:
                bowler = match.group(1).strip()
                batter = match.group(2).strip()
                after_comma = match.group(3).strip()
                parts = after_comma.split()
                if len(parts) >= 2:
                    runs, extra = parts[0], parts[1]
                elif len(parts) == 1:
                    runs = parts[0]

            # Store structured data
            data.append({
                "Over": over,
                "Ball": ball_part,
                "Bowler": bowler,
                "Batter": batter,
                "Runs": runs,
                "Extra": extra,
                "Full_Commentary": commentary
            })

            # --- Display each ball neatly ---
            print(f"Ball: {over}.{ball_part}")
            print(f"  🏏 Bowler: {bowler}")
            print(f"  🧢 Batter: {batter}")
            print(f"  💯 Runs: {runs}")
            print(f"  ⚡ Extra: {extra}")
            print(f"  📋 Commentary: {commentary}\n")

        except Exception as e:
            print(f"⚠️ Skipping {ball_no}: {e}")

    previous_count = len(balls)

    # Scroll to load next batch of balls
    driver.execute_script("window.scrollBy(0, 1500);")
    time.sleep(3)

    # Stop when no new balls appear
    new_balls = driver.find_elements(By.CSS_SELECTOR, 
        "span.ds-text-tight-s.ds-font-regular.ds-mb-1.lg\\:ds-mb-0.lg\\:ds-mr-3.ds-block.ds-text-center.ds-text-typo-mid1")
    if len(new_balls) == previous_count:
        break

# Close the browser
driver.quit()

# Save to CSV
df = pd.DataFrame(data)
df.to_csv("lpl_commentary_structured.csv", index=False, encoding="utf-8-sig")

print("\n✅ Scraping completed successfully!")
print("📂 Data saved to: lpl_commentary_structured.csv")
# Out:
# 🏏 Starting ball-by-ball scraping...
#
# Ball: 19.6
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Ramesh Mendis
#   💯 Runs: 2
#   ⚡ Extra: runs
#   📋 Commentary: Asitha Fernando to Ramesh Mendis, 2 runs Jaffna hold their nerve! What a game, what a finish! Low full-toss, darted on the pads, and all Mendis can do is hack this to deep midwicket. They run back for the second, but the throw is safely into Kusal Mendis's hands. Jaffna win by one run!
#
# Ball: 19.5
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Ramesh Mendis
#   💯 Runs: SIX
#   ⚡ Extra: runs
#   📋 Commentary: Asitha Fernando to Ramesh Mendis, SIX runs And he's found it! Low full-toss and Ramesh Mendis has absolutely smoked this straight down the ground, through the line and all the way
#
# Ball: 19.4
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Ramesh Mendis
#   💯 Runs: 2
#   ⚡ Extra: runs
#   📋 Commentary: Asitha Fernando to Ramesh Mendis, 2 runs Cracking yorker on off, dug out down the ground to long-on. They scramble for a desperate two but the throw misses the stumps
#
# Ball: 19.3
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Ramesh Mendis
#   💯 Runs: FOUR
#   ⚡ Extra: runs
#   📋 Commentary: Asitha Fernando to Ramesh Mendis, FOUR runs Finds the boundary! Full on off, just misses the yorker length. Clears the front leg, frees the arms, high elbow lofted straight drive and there's no chance for long-off
#
# Ball: 19.2
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Ramesh Mendis
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Asitha Fernando to Ramesh Mendis, no run low full-toss chipped to long-on on the bounce. Mendis turns down the single. Was that the right move? Rathnayake is no tailender
#
# Ball: 19.1
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Rathnayake
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Asitha Fernando to Rathnayake, 1 run Starts with an excellent yorker, squeezed out to long-on
#
# Ball: 18.6
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Rathnayake
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Behrendorff to Rathnayake, 1 run Another yorker, low full-toss really, drilled to long-on
#
# Ball: 18.5
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Rathnayake
#   💯 Runs: 2
#   ⚡ Extra: runs
#   📋 Commentary: Behrendorff to Rathnayake, 2 runs Good yorker, whipped to deep midwicket. They hustle back for two
#
# Ball: 18.4
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Rathnayake
#   💯 Runs: SIX
#   ⚡ Extra: runs
#   📋 Commentary: Behrendorff to Rathnayake, SIX runs And it's gone for a maximum! Wow, wow, wow. Misses the yorker and Pavan has just launched this over long-on
#
# Ball: 18.4
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Ramesh Mendis
#   💯 Runs: (no
#   ⚡ Extra: ball)
#   📋 Commentary: Behrendorff to Ramesh Mendis, (no ball) 1 run Balls gone, the BAT'S gone, and it's caught to boot! This was a high full-toss outside off. Mendis hacks at it, and ends up slicing it to backward point, while his bat went to square leg. They go upstairs to check for a waist high no-ball, and the third umpire says it is. Pretty tight in my opinion, but umpire Ruchira Palliyaguruge was certain
#
# Ball: 18.3
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Ramesh Mendis
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Behrendorff to Ramesh Mendis, no run full toss outside off, Mendis goes across the wicket and sweeps it, but straight to backward square leg
#
# Ball: 18.2
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Ramesh Mendis
#   💯 Runs: SIX
#   ⚡ Extra: runs
#   📋 Commentary: Behrendorff to Ramesh Mendis, SIX runs Swivel pulled away over deep midwicket! Skips down the track, it's a back of a length slower ball. His eyes are not really on this, but he goes through the shot and somehow he middles the pants off it
#
# Ball: 18.1
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Ramesh Mendis
#   💯 Runs: FOUR
#   ⚡ Extra: runs
#   📋 Commentary: Behrendorff to Ramesh Mendis, FOUR runs Good start! Back of a length outside, forehand over mid-off, just whacked away
#
# Ball: 17.6
#   🏏 Bowler: Allen
#   🧢 Batter: Ramesh Mendis
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Allen to Ramesh Mendis, 1 run good length on the stumps, nudged to midwicket for one
#
# Ball: 17.5
#   🏏 Bowler: Allen
#   🧢 Batter: Ramesh Mendis
#   💯 Runs: FOUR
#   ⚡ Extra: runs
#   📋 Commentary: Allen to Ramesh Mendis, FOUR runs Reverse sweep for four! This was chipped to Asitha at short third, who is unsure whether to go for the catch or stay back, in the end he's in no man's land and this spins away from him and races away
#
# Ball: 17.4
#   🏏 Bowler: Allen
#   🧢 Batter: Rathnayake
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Allen to Rathnayake, 1 run good length outside off, pushed into the covers off the back foot for one
#
# Ball: 17.3
#   🏏 Bowler: Allen
#   🧢 Batter: Angelo Mathews
#   💯 Runs: OUT
#   ⚡ Extra: Fabian
#   📋 Commentary: Allen to Angelo Mathews, OUT Fabian Allen is having the day of all days! This one is fuller, and arrowed in. Mathews looks to heave this onside and misses. On any other day this is a simply a dot ball, but on Fabian Allen Day, it ricochets off the thigh guard and clatters into the stumps
#
# Ball: 17.2
#   🏏 Bowler: Allen
#   🧢 Batter: Angelo Mathews
#   💯 Runs: 2
#   ⚡ Extra: runs
#   📋 Commentary: Allen to Angelo Mathews, 2 runs good length outside off, this time punched into the covers
#
# Ball: 17.1
#   🏏 Bowler: Allen
#   🧢 Batter: Angelo Mathews
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Allen to Angelo Mathews, no run good length wide outside off, swing and a miss
#
# Ball: 16.6
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Chaturanga
#   💯 Runs: OUT
#   ⚡ Extra: Direct
#   📋 Commentary: Behrendorff to Chaturanga, OUT Direct hit just when they needed it! Chaturanga backs away and drives this fuller one on darted in straight to extra cover. He wants the single but Mathews correctly turns him back. The throw from Nissanka though is a bullet and Chaturanga is barely in the frame
#
# Ball: 16.5
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Angelo Mathews
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Behrendorff to Angelo Mathews, 1 run back of a length on the pads, worked to deep square leg. Just the one
#
# Ball: 16.4
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Angelo Mathews
#   💯 Runs: FOUR
#   ⚡ Extra: runs
#   📋 Commentary: Behrendorff to Angelo Mathews, FOUR runs Clears short fine! Short again, again gets inside the line but this time is able to get enough on it to clear the man in the circle behind square
#
# Ball: 16.3
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Angelo Mathews
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Behrendorff to Angelo Mathews, no run Slower one short of a length, swings and misses. This bounces over leg stump, so no wide given
#
# Ball: 16.2
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Chaturanga
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Behrendorff to Chaturanga, 1 run short of a length just on off, backs away and chops this to mid-off
#
# Ball: 16.1
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Angelo Mathews
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Behrendorff to Angelo Mathews, 1 run Slower one short of a length just outside off, 115kph, controlled pulled to deep square leg
#
# Ball: 15.6
#   🏏 Bowler: Allen
#   🧢 Batter: Shanaka
#   💯 Runs: OUT
#   ⚡ Extra: Allen
#   📋 Commentary: Allen to Shanaka, OUT Allen you absolute beauty! Good length, pitches on leg, grips and turns to strike the top of off stump. Shanaka, the hero last time out, is gone early here as goes for the big slog across the line and misses completely
#
# Ball: 15.5
#   🏏 Bowler: Allen
#   🧢 Batter: Shanaka
#   💯 Runs: 2
#   ⚡ Extra: runs
#   📋 Commentary: Allen to Shanaka, 2 runs good length on the stumps, makes room and pokes this into the offside
#
# Ball: 15.4
#   🏏 Bowler: Allen
#   🧢 Batter: Angelo Mathews
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Allen to Angelo Mathews, 1 run good length on the stumps, worked to long-on off the front foot
#
# Ball: 15.3
#   🏏 Bowler: Allen
#   🧢 Batter: Angelo Mathews
#   💯 Runs: FOUR
#   ⚡ Extra: runs
#   📋 Commentary: Allen to Angelo Mathews, FOUR runs Edged and four! Pushed through quick wide of off, Mathews has a ungainly swing but gets a thick bottom edge past the keeper
#
# Ball: 15.2
#   🏏 Bowler: Allen
#   🧢 Batter: Shanaka
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Allen to Shanaka, 1 run length on off, 92kph, backs away and swats it it square on the off side
#
# Ball: 15.1
#   🏏 Bowler: Allen
#   🧢 Batter: Angelo Mathews
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Allen to Angelo Mathews, 1 run darted on the pads, turned to short fine for one
#
# Ball: 14.6
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Shanaka
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Viyaskanth to Shanaka, no run Huge appeal for leg before! Not out says the umpire. It's the googly and Shanaka has not read it. He is caught on the crease and it's strikes him just above the knee roll. They opt not to review.
#
# Ball: 14.5
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: OUT
#   ⚡ Extra: Huuuuge
#   📋 Commentary: Viyaskanth to Kamindu Mendis, OUT Huuuuge wicket! Viyaskanth has tossed it up, bravely, but this time it's the googly. Kamindu goes once more for the slog sweep but this time he doesn't get the connection. There's still a lot of work to do though at long-on, but DDS makes good ground and holds on to this under pressure
#
# Ball: 14.4
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: SIX
#   ⚡ Extra: runs
#   📋 Commentary: Viyaskanth to Kamindu Mendis, SIX runs Here we go! Kamindu breaks the shackles! This was short of length, Kamindu is waiting on one knee and he just wallops it over deep square leg
#
# Ball: 14.3
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Angelo Mathews
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Viyaskanth to Angelo Mathews, 1 run low full toss but only a single as Mathews swings it away to deep midwicket
#
# Ball: 14.2
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Angelo Mathews
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Viyaskanth to Angelo Mathews, no run wide yorker almost, dug out as point cuts it off
#
# Ball: 14.1
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Viyaskanth to Kamindu Mendis, 1 run good length on the stumps, heaved to wide long-on in the air briefly
#
# Ball: 13.6
#   🏏 Bowler: Dhananjaya
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Dhananjaya to Kamindu Mendis, 1 run full on off, driven to long-off
#
# Ball: 13.5
#   🏏 Bowler: Dhananjaya
#   🧢 Batter: Angelo Mathews
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Dhananjaya to Angelo Mathews, 1 run short of a length on the stumps, clubbed to deep midwicket
#
# Ball: 13.4
#   🏏 Bowler: Dhananjaya
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Dhananjaya to Kamindu Mendis, 1 run tossed up on off, looks for the reverse and just about gets some glove on this. Through the keepers legs
#
# Ball: 13.3
#   🏏 Bowler: Dhananjaya
#   🧢 Batter: Angelo Mathews
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Dhananjaya to Angelo Mathews, 1 run good length on off, dragged to midwicket off the back foot
#
# Ball: 13.2
#   🏏 Bowler: Dhananjaya
#   🧢 Batter: Angelo Mathews
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Dhananjaya to Angelo Mathews, no run good length and flat outside off, play and a miss with little foot movement
#
# Ball: 13.1
#   🏏 Bowler: Dhananjaya
#   🧢 Batter: Angelo Mathews
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Dhananjaya to Angelo Mathews, no run darted in quick on off, 93kph, knocked to Dhananjaya's right as he dives and stops it
#
# Ball: 12.6
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Angelo Mathews
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Viyaskanth to Angelo Mathews, 1 run full outside off, pushes this to long-off for one
#
# Ball: 12.5
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Hasaranga
#   💯 Runs: OUT
#   ⚡ Extra: Viyaskanth
#   📋 Commentary: Viyaskanth to Hasaranga, OUT Viyaskanth has the Kandy skipper! This was tossed up, but it's a good length wide of off. Looks to go against spin and launch it over long-on. Ends up splicing it towards long-off where - who else? - Fabian Allen is lurking to settle under yet another catch
#
# Ball: 12.4
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Viyaskanth to Kamindu Mendis, 1 run short of a length on the stumps, pulled to deep midwicket. Kamindu lets out a groan of frustration
#
# Ball: 12.3
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Hasaranga
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Viyaskanth to Hasaranga, 1 run goes back and nudges this through midwicket for
#
# Ball: 12.2
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Hasaranga
#   💯 Runs: SIX
#   ⚡ Extra: runs
#   📋 Commentary: Viyaskanth to Hasaranga, SIX runs Inside out over extra cover! Another one tossed up, Wanindu makes room, leans back and just launches this into his favoured region
#
# Ball: 12.1
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Hasaranga
#   💯 Runs: FOUR
#   ⚡ Extra: runs
#   📋 Commentary: Viyaskanth to Hasaranga, FOUR runs Well placed! Tossed up on leg, Hasaranga clears the front foot and heaves this between the boundary riders at deep midwicket and long-on
#
# Ball: 11.6
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: FOUR
#   ⚡ Extra: runs
#   📋 Commentary: Asitha Fernando to Kamindu Mendis, FOUR runs Edged for four! Back of a length, angled away from off. Kamindu looks to swing this away over mid-on, but gets a very fortunate inside edge that runs away fine
#
# Ball: 11.5
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Hasaranga
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Asitha Fernando to Hasaranga, 1 run attempted yorker on leg stump, dug out to midwicket for a quick single
#
# Ball: 11.4
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Hasaranga
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Asitha Fernando to Hasaranga, no run Well directed bouncer! Wanindu clears that front leg as a first motion, but this one is right on him as he sways out of the way
#
# Ball: 11.3
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Asitha Fernando to Kamindu Mendis, 1 run skips down the track and swings it down to deep midwicket
#
# Ball: 11.2
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Hasaranga
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Asitha Fernando to Hasaranga, 1 run full on middle and leg, Hasaranga stays deep in the crease and looks to work it onside. Ends up getting a leading edge almost, in the air but well short of long-on
#
# Ball: 11.1
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Asitha Fernando to Kamindu Mendis, 1 run full outside off, slapped straight to mid-off. Kamindu missed out on this one
#
# Ball: 10.6
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Hasaranga
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Viyaskanth to Hasaranga, no run good length just outside off, defensive push to backward point
#
# Ball: 10.5
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Mohammad Haris
#   💯 Runs: OUT
#   ⚡ Extra: Haris's
#   📋 Commentary: Viyaskanth to Mohammad Haris, OUT Haris's wild innings comes to an end! And it's Fabian Allen in the action once again! Haris comes down the track as Viyaskanth holds the length back a touch, looks to hoick it over long on but ends up slicing it high into the Colombo sky. Allen sprints around from long-on and holds on to a very well judged catch
#
# Ball: 10.4
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Viyaskanth to Kamindu Mendis, 1 run darted in on the boots, whipped through square leg
#
# Ball: 10.3
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Mohammad Haris
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Viyaskanth to Mohammad Haris, 1 run goes back and works this through midwicket
#
# Ball: 10.2
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Viyaskanth to Kamindu Mendis, 1 run skips down the track and lifts this into the vacant midwicket region
#
# Ball: 10.1
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Mohammad Haris
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Viyaskanth to Mohammad Haris, 1 run Another hilarious effort from Haris! Looks to take this from outside off and paddle it over fine, ends up scooping it high over the keeper. Falls wide of short third
#
# Ball: 9.6
#   🏏 Bowler: Dhananjaya
#   🧢 Batter: Mohammad Haris
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Dhananjaya to Mohammad Haris, 1 run darted in on the pads as Haris looked to make room. Worked to deep backward square leg
#
# Ball: 9.5
#   🏏 Bowler: Dhananjaya
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Dhananjaya to Kamindu Mendis, 1 run good length on off, gets forward and nurdles this through midwicket for one
#
# Ball: 9.4
#   🏏 Bowler: Dhananjaya
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Dhananjaya to Kamindu Mendis, no run Huge appeal for caught behind as this one slides down leg, Kamindu looks to sweep but doesn't connect. They go upstairs to review, but not sure there was any bat on this. Definitely glances the pad on the way through - likely the sound Mendis heard behind the stumps. Not out.
#
# Ball: 9.3
#   🏏 Bowler: Dhananjaya
#   🧢 Batter: Mohammad Haris
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Dhananjaya to Mohammad Haris, 1 run fuller on the pads, glanced fine for one
#
# Ball: 9.2
#   🏏 Bowler: Dhananjaya
#   🧢 Batter: Mohammad Haris
#   💯 Runs: SIX
#   ⚡ Extra: runs
#   📋 Commentary: Dhananjaya to Mohammad Haris, SIX runs Haris goes hard! Too short from DDS, and this is bread and cheese for Haris who just rocks back and monsters this pull over deep square leg
#
# Ball: 9.1
#   🏏 Bowler: Dhananjaya
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Dhananjaya to Kamindu Mendis, 1 run back of a length on off, punched to long-on
#
# Ball: 8.6
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Mohammad Haris
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Viyaskanth to Mohammad Haris, no run lovely googly, rips back in sharply, and Haris who was caught on the crease does well to get some bat on this. Inside edge into his pads
#
# Ball: 8.5
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Mohammad Haris
#   💯 Runs: 2
#   ⚡ Extra: runs
#   📋 Commentary: Viyaskanth to Mohammad Haris, 2 runs good length on off, again. Reverse sweep, chipped high and just beats the man at short third
#
# Ball: 8.4
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Mohammad Haris
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Viyaskanth to Mohammad Haris, no run good length just outside off, 91kph, gives this one a little more air. Misses the cut
#
# Ball: 8.3
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Viyaskanth to Kamindu Mendis, 1 run good length on the stumps, 95kph, swept to deep square leg
#
# Ball: 8.2
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: 2
#   ⚡ Extra: runs
#   📋 Commentary: Viyaskanth to Kamindu Mendis, 2 runs short of a length, 99kph, on the stumps, worked to the left of long-on for a couple
#
# Ball: 8.1
#   🏏 Bowler: Viyaskanth
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Viyaskanth to Kamindu Mendis, no run good length outside off, 91kph, comes down the track but straight back to the bowler
#
# Ball: 7.6
#   🏏 Bowler: Dhananjaya
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Dhananjaya to Kamindu Mendis, 1 run swept behind square now for a single
#
# Ball: 7.5
#   🏏 Bowler: Dhananjaya
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: FOUR
#   ⚡ Extra: runs
#   📋 Commentary: Dhananjaya to Kamindu Mendis, FOUR runs Clears the extra cover! Tossed up outside off and Kamindu executes this cover drive to perfection
#
# Ball: 7.4
#   🏏 Bowler: Dhananjaya
#   🧢 Batter: Mohammad Haris
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Dhananjaya to Mohammad Haris, 1 run short of a length on the stumps, pulled to deep midwicket
#
# Ball: 7.3
#   🏏 Bowler: Dhananjaya
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Dhananjaya to Kamindu Mendis, 1 run back of a length, pushed through flatter on off. Pulled to long-on
#
# Ball: 7.2
#   🏏 Bowler: Dhananjaya
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Dhananjaya to Kamindu Mendis, no run full and wide, slapped straight to short extra cover
#
# Ball: 7.1
#   🏏 Bowler: Dhananjaya
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: 2
#   ⚡ Extra: runs
#   📋 Commentary: Dhananjaya to Kamindu Mendis, 2 runs good length outside off from around the wicket, driven into the covers for a couple
#
# Ball: 6.6
#   🏏 Bowler: Allen
#   🧢 Batter: Mohammad Haris
#   💯 Runs: 2
#   ⚡ Extra: runs
#   📋 Commentary: Allen to Mohammad Haris, 2 runs fuller on off, driven wide of long-off for a couple
#
# Ball: 6.5
#   🏏 Bowler: Allen
#   🧢 Batter: Mohammad Haris
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Allen to Mohammad Haris, no run short of a length outside off, cut square straight to cover
#
# Ball: 6.4
#   🏏 Bowler: Allen
#   🧢 Batter: Kamindu Mendis
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Allen to Kamindu Mendis, 1 run tossed up outside off from over the wicket, steps across and works it through midwicket
#
# Ball: 6.3
#   🏏 Bowler: Allen
#   🧢 Batter: Fletcher
#   💯 Runs: OUT
#   ⚡ Extra: And
#   📋 Commentary: Allen to Fletcher, OUT And this time it's right through him! Very similar to the last one but this one is straighter. Fletcher again shapes up to cut but has to adjust late. Doesn't read the arm ball and looks to just block, but he's late on the stroke as this zips through to crash into off stump
#
# Ball: 6.2
#   🏏 Bowler: Allen
#   🧢 Batter: Fletcher
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Allen to Fletcher, no run this one is pushed through quicker outside off as Fletcher chops it on to his pads
#
# Ball: 6.1
#   🏏 Bowler: Allen
#   🧢 Batter: Fletcher
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Allen to Fletcher, no run grip and turn away from off, as Fletcher makes too much room on the leg side
#
# Ball: 5.6
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Mohammad Haris
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Asitha Fernando to Mohammad Haris, no run slower one outside off on a length, cuts and gets an edge but it bounces through to the keeper
#
# Ball: 5.5
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Fletcher
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Asitha Fernando to Fletcher, 1 run full on the pads, clipped to deep backward square leg. Fletcher hobbles gingerly to the other side
#
# Ball: 5.4
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Fletcher
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Asitha Fernando to Fletcher, no run cracking yorker, squeezed out just about
#
# Ball: 5.3
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Mohammad Haris
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Asitha Fernando to Mohammad Haris, 1 run pulled to deep square leg for one
#
# Ball: 5.2
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Mohammad Haris
#   💯 Runs: SIX
#   ⚡ Extra: runs
#   📋 Commentary: Asitha Fernando to Mohammad Haris, SIX runs What an unreal shot! How do I even describe it? Reverse swat, off the back of the bat that has just flown fine of short third man all the way for six! Just how, it was a low full-toss as well
#
# Ball: 5.2
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Mohammad Haris
#   💯 Runs: 1
#   ⚡ Extra: wide
#   📋 Commentary: Asitha Fernando to Mohammad Haris, 1 wide looks for another yorker, but slides down leg. Wide given as the bowler thinks there's something on it
#
# Ball: 5.1
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Fletcher
#   💯 Runs: 1
#   ⚡ Extra: leg
#   📋 Commentary: Asitha Fernando to Fletcher, 1 leg bye Lovely yorker, just manages to squeeze this behind square on the leg side for one. Seems to have missed the bat and on to the boot
#
# Ball: 4.6
#   🏏 Bowler: Allen
#   🧢 Batter: Mohammad Haris
#   💯 Runs: FOUR
#   ⚡ Extra: runs
#   📋 Commentary: Allen to Mohammad Haris, FOUR runs Clubbed down the ground! Tossed up on leg, backs away, leans back and smacks it down the ground. Beats long-off. 50 up for Kandy
#
# Ball: 4.5
#   🏏 Bowler: Allen
#   🧢 Batter: Mohammad Haris
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Allen to Mohammad Haris, no run skips down the track and looks to heave this against the spin. Inside edge into the pads
#
# Ball: 4.4
#   🏏 Bowler: Allen
#   🧢 Batter: Mohammad Haris
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Allen to Mohammad Haris, no run back of a length just outside off, looks to cut and misses as this turns away from the right hander
#
# Ball: 4.3
#   🏏 Bowler: Allen
#   🧢 Batter: Mohammad Haris
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Allen to Mohammad Haris, no run full on the stumps, hacked to mid-on
#
# Ball: 4.2
#   🏏 Bowler: Allen
#   🧢 Batter: Mohammad Haris
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Allen to Mohammad Haris, no run Full outside off, squeezed to mid-off
#
# Ball: 4.1
#   🏏 Bowler: Allen
#   🧢 Batter: Chandimal
#   💯 Runs: OUT
#   ⚡ Extra: Chandimal
#   📋 Commentary: Allen to Chandimal, OUT Chandimal is gone! Allen is ecstatic! This one drifted in full and deflects straight off Chandimal's boot before careening into middle stump. The Kandy coach has his head in his hands, he knows how important that wicket is
#
# Ball: 3.6
#   🏏 Bowler: Azmatullah
#   🧢 Batter: Fletcher
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Azmatullah to Fletcher, no run Searing yorker, and one that Fletcher has done really well to just keep out
#
# Ball: 3.5
#   🏏 Bowler: Azmatullah
#   🧢 Batter: Fletcher
#   💯 Runs: FOUR
#   ⚡ Extra: runs
#   📋 Commentary: Azmatullah to Fletcher, FOUR runs Lifted over backward point! Back of a length outside off, skips down the track, adjusts to the short length, uses the pace and just lifts it over the infield
#
# Ball: 3.4
#   🏏 Bowler: Azmatullah
#   🧢 Batter: Fletcher
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Azmatullah to Fletcher, no run Shuffles down the track again, this time looks to go through the offside, but it's slapped straight to mid-off
#
# Ball: 3.3
#   🏏 Bowler: Azmatullah
#   🧢 Batter: Fletcher
#   💯 Runs: SIX
#   ⚡ Extra: runs
#   📋 Commentary: Azmatullah to Fletcher, SIX runs Three in three! Skips down the track, makes this slower length ball into a fuller one and just launches it over cow corner
#
# Ball: 3.2
#   🏏 Bowler: Azmatullah
#   🧢 Batter: Fletcher
#   💯 Runs: SIX
#   ⚡ Extra: runs
#   📋 Commentary: Azmatullah to Fletcher, SIX runs Even bigger! Drags the length back but same result. Just a short-arm jab but this sails over deep midwicket!
#
# Ball: 3.1
#   🏏 Bowler: Azmatullah
#   🧢 Batter: Fletcher
#   💯 Runs: SIX
#   ⚡ Extra: runs
#   📋 Commentary: Azmatullah to Fletcher, SIX runs Greeted with a six! So, so good from Fletcher. Good length but too straight. He gets inside the line and just flicks it over deep backward square leg
#
# Ball: 2.6
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Chandimal
#   💯 Runs: FOUR
#   ⚡ Extra: runs
#   📋 Commentary: Behrendorff to Chandimal, FOUR runs And salt in the wounds! Short of a length and this pull has been clattered in front of square
#
# Ball: 2.5
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Fletcher
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Behrendorff to Fletcher, 1 run Nearly a run out! Another one pace-off and Fletcher dabs it to backward point. The run is just not on but they take it. All the man has to do is hit the stumps but he misses. Chandimal would have been out my metres
#
# Ball: 2.4
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Fletcher
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Behrendorff to Fletcher, no run Swing and a miss! Back of length on the stumps. Looks to pull this but is early on the stroker
#
# Ball: 2.3
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Fletcher
#   💯 Runs: FOUR
#   ⚡ Extra: runs
#   📋 Commentary: Behrendorff to Fletcher, FOUR runs Muscled away! Good length just outside, Fletcher just hacks across the line and beats the diving midwicket. Not much timing but a lot of power
#
# Ball: 2.2
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Fletcher
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Behrendorff to Fletcher, no run Good length, pace-off, wicket to wicket. Appeal for leg before and given! Insta-review from Fletcher! And the replays vindicate him, clear inside edge on this. It might have been pitching just outside leg as well
#
# Ball: 2.1
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Chandimal
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Behrendorff to Chandimal, 1 run back of a length on off, push and run towards cover
#
# Ball: 1.6
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Fletcher
#   💯 Runs: FOUR
#   ⚡ Extra: runs
#   📋 Commentary: Asitha Fernando to Fletcher, FOUR runs Just about clears short fine leg! Back of a length but on leg, gets inside the line and whips it fine. Behrendorff has height on his side, but even he can't leap and grab this one
#
# Ball: 1.5
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Fletcher
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Asitha Fernando to Fletcher, no run back of a length, and hurries him this time. Looks to cut but this is too close to him, inside edge into the pads
#
# Ball: 1.4
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Fletcher
#   💯 Runs: SIX
#   ⚡ Extra: runs
#   📋 Commentary: Asitha Fernando to Fletcher, SIX runs Glorious! Good length on off, but this drive from Fletcher is oustanding. Sumptuous check-drive straight into the sightscreen, quality stuff
#
# Ball: 1.3
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Fletcher
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Asitha Fernando to Fletcher, no run full on the pads, whipped straight to midwicket
#
# Ball: 1.2
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Chandimal
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Asitha Fernando to Chandimal, 1 run Whipped away, but somehow the man at deep backward square saves the boundary! Back of a length on middle and Chandimal picks it up, it races to the boundary rider but he does well to just get his body behind it
#
# Ball: 1.1
#   🏏 Bowler: Asitha Fernando
#   🧢 Batter: Chandimal
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Asitha Fernando to Chandimal, no run back of a length on off, defended into the turf off the back foot
#
# Ball: 0.6
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Fletcher
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Behrendorff to Fletcher, no run back of a length outside off, dabbed straight to backward point
#
# Ball: 0.5
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Chandimal
#   💯 Runs: 1
#   ⚡ Extra: run
#   📋 Commentary: Behrendorff to Chandimal, 1 run back of a length on off, runs this down behind point for one
#
# Ball: 0.4
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Chandimal
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Behrendorff to Chandimal, no run back of a length, nips in and cramps Chandimal for room
#
# Ball: 0.3
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Chandimal
#   💯 Runs: FOUR
#   ⚡ Extra: runs
#   📋 Commentary: Behrendorff to Chandimal, FOUR runs Chipped through midwicket! This was fuller and shaping in a touch on middle and leg, but Chandimal does well to get that front foot out of the way and flicks it away
#
# Ball: 0.2
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Chandimal
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Behrendorff to Chandimal, no run Good carry! Back of a length, pitches on middle and leg and goes across the right hander. Beats him well
#
# Ball: 0.1
#   🏏 Bowler: Behrendorff
#   🧢 Batter: Chandimal
#   💯 Runs: no
#   ⚡ Extra: run
#   📋 Commentary: Behrendorff to Chandimal, no run back of a length on off, defended off the back foot
#
#
# ✅ Scraping completed successfully!
# 📂 Data saved to: lpl_commentary_structured.csv
